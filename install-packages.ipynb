# %% [markdown]
# # Installing Packages
#
# If there is a Python or R package not available in the data science lab image, you can _temporarily_ install it.
#
# You can do that by running a bash command inside a notebook cell that will call either the `mamba`, `conda` or `pip` commands.

# %% [markdown]
# ## Installing packages with Anaconda
#
# ```
# !conda install -y -c conda-forge <list-of-packages>
# ```
# or
# ```
# !mamba install -q -y -c conda-forge <list-of-packages>
# ```
#
# You can search for packages in https://anaconda.org/
#
# Prefer using packages from the `conda-forge` owner.

# %%
# !mamba install -q -y -c conda-forge python-levenshtein fuzzywuzzy
# Out:
#   Package             Version  Build           Channel                   Size
# ───────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────
#
#   fuzzywuzzy           0.18.0  pyhd8ed1ab_0    conda-forge/noarch       22 KB
#   python-levenshtein   0.12.2  py39h3811e60_0  conda-forge/linux-64     80 KB
#
#   Summary:
#
#   Install: 2 packages
#
#   Total download: 102 KB
#
# ───────────────────────────────────────────────────────────────────────────────
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %% [markdown]
# ## Installing Python packages with pip
#
# `!pip install <list-of-packages>`
#
# You can search for packages in https://pypi.org/

# %%
# !pip install "elasticsearch>=5.0.0,<6.0.0"
# Out:
# Collecting elasticsearch<6.0.0,>=5.0.0
#   Downloading elasticsearch-5.5.3-py2.py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 29.9 MB/s eta 0:00:01
# Requirement already satisfied: urllib3>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from elasticsearch<6.0.0,>=5.0.0) (1.26.6)
# Installing collected packages: elasticsearch
#   Attempting uninstall: elasticsearch
#     Found existing installation: elasticsearch 7.13.4
#     Uninstalling elasticsearch-7.13.4:
#       Successfully uninstalled elasticsearch-7.13.4
# Successfully installed elasticsearch-5.5.3

# %% [markdown]
# ## Installing CRAN R packages with Anaconda
#
# If there is R package that is exists in CRAN, but not in the Anaconda repository, you can install it by running the `install.packages` R command inside the conda command.
#
# ```
# !mamba -q run R -e "install.packages(\
#     '<package-name>',\
#     lib='/opt/conda/lib/R/library',\
#     repos='http://cran.us.r-project.org'\
# )"
# ```

# %%
# !mamba run R -e "install.packages(\
    'googleAnalyticsR',\
    lib='/opt/conda/lib/R/library',\
    repos='http://cran.us.r-project.org'\
)"
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.14.1) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# R version 4.1.0 (2021-05-18) -- "Camp Pontanezen"
# Copyright (C) 2021 The R Foundation for Statistical Computing
# Platform: x86_64-conda-linux-gnu (64-bit)
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under certain conditions.
# Type 'license()' or 'licence()' for distribution details.
#
#   Natural language support but running in an English locale
#
# R is a collaborative project with many contributors.
# Type 'contributors()' for more information and
# 'citation()' on how to cite R or R packages in publications.
#
# Type 'demo()' for some demos, 'help()' for on-line help, or
# 'help.start()' for an HTML browser interface to help.
# Type 'q()' to quit R.
#
# > install.packages(     'googleAnalyticsR',     lib='/opt/conda/lib/R/library',     repos='http://cran.us.r-project.org' )
# ℹ 2021-09-29 21:30:01 > No consent file found
# ℹ 2021-09-29 21:30:02 > No consent file found
# ℹ 2021-09-29 21:30:07 > No consent file found
# ℹ 2021-09-29 21:30:08 > No consent file found
# >
# >
#
# also installing the dependencies ‘googleAuthR’, ‘measurementProtocol’
#
# trying URL 'http://cran.us.r-project.org/src/contrib/googleAuthR_1.4.0.tar.gz'
# Content type 'application/x-gzip' length 216292 bytes (211 KB)
# ==================================================
# downloaded 211 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/measurementProtocol_0.1.0.tar.gz'
# Content type 'application/x-gzip' length 12455 bytes (12 KB)
# ==================================================
# downloaded 12 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/googleAnalyticsR_1.0.0.tar.gz'
# Content type 'application/x-gzip' length 803362 bytes (784 KB)
# ==================================================
# downloaded 784 KB
#
# * installing *source* package ‘googleAuthR’ ...
# ** package ‘googleAuthR’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (googleAuthR)
# * installing *source* package ‘measurementProtocol’ ...
# ** package ‘measurementProtocol’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (measurementProtocol)
# * installing *source* package ‘googleAnalyticsR’ ...
# ** package ‘googleAnalyticsR’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (googleAnalyticsR)
#
# The downloaded source packages are in
# 	‘/tmp/RtmpLYnm5o/downloaded_packages’
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %% [markdown]
# ## Running anaconda command to install packages inside a R kernel
#
# The Jupyter R kernel doesn't have the `!` magic cell that allows you to run terminal commands, it is available only for the Python kernel.
#
# In that case, you should use the `system` R function. Simply create a cell and call the function inside it:
# ```
# system("!mamba install -q -y -c conda-forge r-igraph r-multidplyr", intern=TRUE)
# ```
#
# The `intern=TRUE` is to show the standard output of the command inside the notebook cell output.

# %% [markdown]
# ## conda vs mamba
#
# You can use the `conda` and `mamba` commands interchangeably.
#
# [Mamba](https://github.com/mamba-org/mamba) is a reimplementation of the conda package manager in C++, running much faster than the original conda implementation.
#
# **We highly recommend using `mamba` instead of `conda`, since it is much faster.**

# %% [markdown]
# ## Anaconda vs pip
#
# Installing packages with `mamba` is the preferred way since it is less prune to errors, because it has pre-compiled packages and will correctly solve dependencies (differently from `pip`), and will be much faster than `conda`.
#
# Anaconda works not only for Python, but for any software (C, C++, Scala, R, Julia, etc).
#
# The disadvantage of `conda` is that, depending on the complexity of the package, it might take some time to install. But this problem of performance is alleviated when using `mamba` instead of `conda`.
#
# If you want to speed the installation of a **Python** package, you can use `pip`, just make sure that it will be correctly installed and will not break other packages.

# %% [markdown]
# ## Persistency
#
# After installing a package, it will be available to be loaded and used in all of your notebooks.
#
# The package remains installed as long as the docker container is running.
#
# If the container is restarted, the environment will be reloaded to its default configuration, so the package will not be available anymore and you will have to reinstall it.
#
# **We recommend that you create a cell in the top of your notebook with the `!mamba`, `!conda`, or `!pip` that installs all the extra libraries needed for your notebook to run.**
#
# This way you guarantee that your notebook will correctly run all the times, even if it runs on a fresh environment.

# %% [markdown]
# ## Requesting packages
#
# If you have an idea of a package to be included by default in the data science lab image (so that you wouldn't need to install it) create an issue in the GitHub repository asking for it!
#
# https://github.com/seek-ai/shared-datascience-lab/issues

# %% [markdown]
# ## Updating all packages
#
# It is possible to update all the anaconda packages in the environment with one command.

# %%
# !mamba update -q -y --all
# Out:
#   Package                      Version  Build                   Channel                    Size
# ─────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────────────────────
#
#   brotli-bin                     1.0.9  h7f98852_5              conda-forge/linux-64      19 KB
#   debugpy                        1.4.1  py39he80948d_0          conda-forge/linux-64       2 MB
#   importlib_resources            5.2.2  pyhd8ed1ab_0            conda-forge/noarch        21 KB
#   libbrotlicommon                1.0.9  h7f98852_5              conda-forge/linux-64      65 KB
#   libbrotlidec                   1.0.9  h7f98852_5              conda-forge/linux-64      33 KB
#   libbrotlienc                   1.0.9  h7f98852_5              conda-forge/linux-64     286 KB
#   libsanitizer                   9.4.0  h79bfe98_9              conda-forge/linux-64       7 MB
#   modin-core                    0.11.0  py39hf3d152e_0          conda-forge/linux-64     952 KB
#   modin-dask                    0.11.0  py39hf3d152e_0          conda-forge/linux-64      10 KB
#   r-e1071                        1.7_9  r41h03ef668_0           conda-forge/linux-64     842 KB
#   r-fontawesome                  0.2.2  r41hc72bb7e_0           conda-forge/noarch         1 MB
#   r-future.apply                 1.8.1  r41hc72bb7e_0           conda-forge/noarch       164 KB
#   r-lobstr                       1.1.1  r41h03ef668_1           conda-forge/linux-64     153 KB
#   r-progressr                    0.9.0  r41hc72bb7e_0           conda-forge/noarch       272 KB
#   r-proxy                       0.4_26  r41hcfec24a_0           conda-forge/linux-64     231 KB
#   r-tzdb                         0.1.2  r41h03ef668_2           conda-forge/linux-64     508 KB
#   r-vroom                        1.5.5  r41h03ef668_1           conda-forge/linux-64     953 KB
#
#   Change:
# ─────────────────────────────────────────────────────────────────────────────────────────────────
#
#   argon2-cffi                   20.1.0  py39h3811e60_2          installed
#   argon2-cffi                   20.1.0  py39hbd71b63_2          conda-forge/linux-64      47 KB
#   bottleneck                     1.3.2  py39hce5d2b2_3          installed
#   bottleneck                     1.3.2  py39hce5d2b2_4          conda-forge/linux-64     129 KB
#   brotli                         1.0.9  h9c3ff4c_4              installed
#   brotli                         1.0.9  h7f98852_5              conda-forge/linux-64      17 KB
#   brunsli                          0.1  h9c3ff4c_0              installed
#   brunsli                          0.1  he1b5a44_0              conda-forge/linux-64     196 KB
#   entrypoints                      0.3  pyhd8ed1ab_1003         installed
#   entrypoints                      0.3  py39hde42818_1002       conda-forge/linux-64      11 KB
#   giflib                         5.2.1  h36c2ea0_2              installed
#   giflib                         5.2.1  h516909a_2              conda-forge/linux-64      80 KB
#   jpeg                              9d  h36c2ea0_0              installed
#   jpeg                              9d  h516909a_0              conda-forge/linux-64     266 KB
#   jupyter_console                6.4.0  pyhd8ed1ab_1            installed
#   jupyter_console                6.4.0  pyhd8ed1ab_0            conda-forge/noarch        22 KB
#   jxrlib                           1.1  h7f98852_2              installed
#   jxrlib                           1.1  h516909a_2              conda-forge/linux-64     236 KB
#   kernel-headers_linux-64       2.6.32  h77966d4_13             installed
#   kernel-headers_linux-64       2.6.32  he073ed8_14             conda-forge/noarch       708 KB
#   libblas                        3.9.0  9_openblas              installed
#   libblas                        3.9.0  11_linux64_openblas     conda-forge/linux-64      12 KB
#   libcblas                       3.9.0  9_openblas              installed
#   libcblas                       3.9.0  11_linux64_openblas     conda-forge/linux-64      11 KB
#   liblapack                      3.9.0  9_openblas              installed
#   liblapack                      3.9.0  11_linux64_openblas     conda-forge/linux-64      11 KB
#   libnghttp2                    1.43.0  h812cca2_0              installed
#   libnghttp2                    1.43.0  h812cca2_1              conda-forge/linux-64     790 KB
#   libpng                        1.6.37  h21135ba_2              installed
#   libpng                        1.6.37  hed695b0_2              conda-forge/linux-64     359 KB
#   libsodium                     1.0.18  h36c2ea0_1              installed
#   libsodium                     1.0.18  h516909a_1              conda-forge/linux-64     366 KB
#   libzopfli                      1.0.3  h9c3ff4c_0              installed
#   libzopfli                      1.0.3  he1b5a44_0              conda-forge/linux-64     178 KB
#   lz4-c                          1.9.3  h9c3ff4c_0              installed
#   lz4-c                          1.9.3  h9c3ff4c_1              conda-forge/linux-64     179 KB
#   pickleshare                    0.7.5  py_1003                 installed
#   pickleshare                    0.7.5  py39hde42818_1002       conda-forge/linux-64      13 KB
#   pytables                       3.6.1  py39hf6dc253_3          installed
#   pytables                       3.6.1  py39h2669a42_4          conda-forge/linux-64       2 MB
#   pyyaml                         5.4.1  py39h3811e60_0          installed
#   pyyaml                         5.4.1  py39h3811e60_1          conda-forge/linux-64     196 KB
#   rpy2                           3.4.5  py39r41hce5d2b2_0       installed
#   rpy2                           3.4.5  py39r41hce5d2b2_1       conda-forge/linux-64     377 KB
#   sqlite                        3.36.0  h9cd32fc_0              installed
#   sqlite                        3.36.0  h9cd32fc_2              conda-forge/linux-64       1 MB
#   sysroot_linux-64                2.12  h77966d4_13             installed
#   sysroot_linux-64                2.12  he073ed8_14             conda-forge/noarch        32 MB
#   tzdata                         2021a  he74cb21_0              installed
#   tzdata                         2021a  he74cb21_1              conda-forge/noarch       121 KB
#   zeromq                         4.3.4  h9c3ff4c_0              installed
#   zeromq                         4.3.4  h9c3ff4c_1              conda-forge/linux-64     351 KB
#   zfp                            0.5.5  h9c3ff4c_5              installed
#   zfp                            0.5.5  h9c3ff4c_7              conda-forge/linux-64     189 KB
#
#   Upgrade:
# ─────────────────────────────────────────────────────────────────────────────────────────────────
#
#   alembic                        1.6.5  pyhd8ed1ab_0            installed
#   alembic                        1.7.3  pyhd8ed1ab_0            conda-forge/noarch       135 KB
#   anyio                          3.2.1  py39hf3d152e_0          installed
#   anyio                          3.3.2  py39hf3d152e_0          conda-forge/linux-64     148 KB
#   arrow-cpp                      4.0.1  py39h881cbb8_2_cpu      installed
#   arrow-cpp                      5.0.0  py39h247a7eb_8_cpu      conda-forge/linux-64      23 MB
#   awswrangler                    2.9.0  pyhd8ed1ab_0            installed
#   awswrangler                   2.11.0  pyhd8ed1ab_0            conda-forge/noarch       118 KB
#   beautifulsoup4                 4.9.3  pyhb0f4dca_0            installed
#   beautifulsoup4                4.10.0  pyha770c72_0            conda-forge/noarch        77 KB
#   binutils_impl_linux-64        2.35.1  h193b22a_2              installed
#   binutils_impl_linux-64        2.36.1  h193b22a_2              conda-forge/linux-64      10 MB
#   binutils_linux-64               2.35  h67ddf6f_30             installed
#   binutils_linux-64               2.36  hf3e587d_1              conda-forge/linux-64      23 KB
#   bleach                         3.3.0  pyh44b312d_0            installed
#   bleach                         4.1.0  pyhd8ed1ab_0            conda-forge/noarch       121 KB
#   bokeh                          2.3.2  py39hf3d152e_0          installed
#   bokeh                          2.4.0  py39hf3d152e_0          conda-forge/linux-64      14 MB
#   c-ares                        1.17.1  h7f98852_1              installed
#   c-ares                        1.17.2  h7f98852_0              conda-forge/linux-64     109 KB
#   cffi                          1.14.5  py39he32792d_0          installed
#   cffi                          1.14.6  py39he32792d_0          conda-forge/linux-64     227 KB
#   cloudpickle                    1.6.0  py_0                    installed
#   cloudpickle                    2.0.0  pyhd8ed1ab_0            conda-forge/noarch        24 KB
#   configurable-http-proxy        4.4.0  node15_he6ea98c_0       installed
#   configurable-http-proxy        4.5.0  node15_he6ea98c_0       conda-forge/linux-64       2 MB
#   confuse                        1.5.0  pyhd8ed1ab_0            installed
#   confuse                        1.6.0  pyhd8ed1ab_0            conda-forge/noarch        22 KB
#   curl                          7.77.0  hea6ffbf_0              installed
#   curl                          7.79.1  h2574ce0_1              conda-forge/linux-64     153 KB
#   cython                       0.29.23  py39he80948d_1          installed
#   cython                       0.29.24  py39he80948d_0          conda-forge/linux-64       2 MB
#   dask                        2021.6.2  pyhd8ed1ab_0            installed
#   dask                        2021.9.1  pyhd8ed1ab_0            conda-forge/noarch         4 KB
#   dask-core                   2021.6.2  pyhd8ed1ab_0            installed
#   dask-core                   2021.9.1  pyhd8ed1ab_0            conda-forge/noarch       768 KB
#   distributed                 2021.6.2  py39hf3d152e_0          installed
#   distributed                 2021.9.1  py39hf3d152e_0          conda-forge/linux-64       1 MB
#   elasticsearch                 7.13.4  pyhd8ed1ab_0            installed
#   elasticsearch                 7.15.0  pyhd8ed1ab_0            conda-forge/noarch       134 KB
#   fsspec                      2021.6.1  pyhd8ed1ab_0            installed
#   fsspec                      2021.9.0  pyhd8ed1ab_0            conda-forge/noarch        84 KB
#   gcc_impl_linux-64              9.3.0  h70c0ae5_19             installed
#   gcc_impl_linux-64              9.4.0  h03d3576_9              conda-forge/linux-64      46 MB
#   gcc_linux-64                   9.3.0  hf25ea35_30             installed
#   gcc_linux-64                   9.4.0  h391b98a_1              conda-forge/linux-64      24 KB
#   gfortran_impl_linux-64         9.3.0  hc4a2995_19             installed
#   gfortran_impl_linux-64         9.4.0  h0003116_9              conda-forge/linux-64      10 MB
#   gfortran_linux-64              9.3.0  hdc58fab_30             installed
#   gfortran_linux-64              9.4.0  hf0ab688_1              conda-forge/linux-64      23 KB
#   glib                          2.68.3  h9c3ff4c_0              installed
#   glib                          2.68.4  h9c3ff4c_0              conda-forge/linux-64     447 KB
#   glib-tools                    2.68.3  h9c3ff4c_0              installed
#   glib-tools                    2.68.4  h9c3ff4c_0              conda-forge/linux-64      86 KB
#   google-auth                    2.2.0  pyh6c4a22f_0            installed
#   google-auth                    2.2.1  pyh6c4a22f_0            conda-forge/noarch        82 KB
#   graphviz                      2.47.3  h85b4f2f_0              installed
#   graphviz                      2.49.0  h85b4f2f_0              conda-forge/linux-64       4 MB
#   greenlet                       1.1.0  py39he80948d_0          installed
#   greenlet                       1.1.2  py39he80948d_0          conda-forge/linux-64      90 KB
#   grpc-cpp                      1.38.1  h36ce80c_0              installed
#   grpc-cpp                      1.40.0  h05f19cf_1              conda-forge/linux-64       4 MB
#   gsl                              2.6  he838d99_2              installed
#   gsl                              2.7  he838d99_0              conda-forge/linux-64       3 MB
#   gst-plugins-base              1.18.4  hf529b03_2              installed
#   gst-plugins-base              1.18.5  hf529b03_0              conda-forge/linux-64       3 MB
#   gstreamer                     1.18.4  h76c114f_2              installed
#   gstreamer                     1.18.5  h76c114f_0              conda-forge/linux-64       2 MB
#   gxx_impl_linux-64              9.3.0  hd87eabc_19             installed
#   gxx_impl_linux-64              9.4.0  h03d3576_9              conda-forge/linux-64      11 MB
#   gxx_linux-64                   9.3.0  h3fbe746_30             installed
#   gxx_linux-64                   9.4.0  h0316aca_1              conda-forge/linux-64      23 KB
#   h5py                           3.2.1  nompi_py39h98ba4bc_100  installed
#   h5py                           3.4.0  nompi_py39h7e08c79_101  conda-forge/linux-64       1 MB
#   harfbuzz                       2.8.1  h83ec7ef_0              installed
#   harfbuzz                       2.9.1  h83ec7ef_0              conda-forge/linux-64       2 MB
#   hdf5                          1.10.6  nompi_h6a2412b_1114     installed
#   hdf5                          1.12.1  nompi_h2750804_100      conda-forge/linux-64       4 MB
#   imagecodecs                 2021.6.8  py39h44211f0_0          installed
#   imagecodecs                2021.7.30  py39h44211f0_1          conda-forge/linux-64       7 MB
#   imagemagick                7.0.11_14  pl5320hb118871_0        installed
#   imagemagick                  7.1.0_8  pl5321hb118871_0        conda-forge/linux-64       3 MB
#   importlib-metadata             4.6.0  py39hf3d152e_0          installed
#   importlib-metadata             4.8.1  py39hf3d152e_0          conda-forge/linux-64      32 KB
#   ipykernel                      5.5.5  py39hef51801_0          installed
#   ipykernel                      6.4.1  py39hef51801_0          conda-forge/linux-64     174 KB
#   ipympl                         0.7.0  pyhd8ed1ab_0            installed
#   ipympl                         0.8.0  pyhd8ed1ab_0            conda-forge/noarch        40 KB
#   ipyparallel                    6.3.0  py39hf3d152e_2          installed
#   ipyparallel                    7.0.1  pyhd8ed1ab_0            conda-forge/noarch       225 KB
#   ipython                       7.25.0  py39hef51801_0          installed
#   ipython                       7.28.0  py39hef51801_0          conda-forge/linux-64       1 MB
#   ipywidgets                     7.6.3  pyhd3deb0d_0            installed
#   ipywidgets                     7.6.5  pyhd8ed1ab_0            conda-forge/noarch       101 KB
#   jupyter_client                6.1.12  pyhd8ed1ab_0            installed
#   jupyter_client                 7.0.5  pyhd8ed1ab_0            conda-forge/noarch        86 KB
#   jupyter_core                   4.7.1  py39hf3d152e_0          installed
#   jupyter_core                   4.8.1  py39hf3d152e_0          conda-forge/linux-64      79 KB
#   jupyter_server                 1.9.0  pyhd8ed1ab_0            installed
#   jupyter_server                1.11.0  pyhd8ed1ab_0            conda-forge/noarch       269 KB
#   jupyterhub                     1.4.1  py39hf3d152e_0          installed
#   jupyterhub                     1.4.2  py39hf3d152e_0          conda-forge/linux-64       5 KB
#   jupyterhub-base                1.4.1  py39hf3d152e_0          installed
#   jupyterhub-base                1.4.2  py39hf3d152e_0          conda-forge/linux-64       2 MB
#   jupyterlab                    3.0.16  pyhd8ed1ab_0            installed
#   jupyterlab                    3.1.14  pyhd8ed1ab_0            conda-forge/noarch         6 MB
#   jupyterlab_server              2.6.0  pyhd8ed1ab_0            installed
#   jupyterlab_server              2.8.2  pyhd8ed1ab_0            conda-forge/noarch        45 KB
#   jupyterlab_widgets             1.0.0  pyhd8ed1ab_1            installed
#   jupyterlab_widgets             1.0.2  pyhd8ed1ab_0            conda-forge/noarch       130 KB
#   kiwisolver                     1.3.1  py39h1a9c180_1          installed
#   kiwisolver                     1.3.2  py39h1a9c180_0          conda-forge/linux-64      79 KB
#   krb5                          1.19.1  hcc1bbae_0              installed
#   krb5                          1.19.2  hcc1bbae_2              conda-forge/linux-64       1 MB
#   ld_impl_linux-64              2.35.1  hea4e1c9_2              installed
#   ld_impl_linux-64              2.36.1  hea4e1c9_2              conda-forge/linux-64     667 KB
#   libaec                         1.0.5  h9c3ff4c_0              installed
#   libaec                         1.0.6  h9c3ff4c_0              conda-forge/linux-64      45 KB
#   libarchive                     3.5.1  hccf745f_2              installed
#   libarchive                     3.5.2  hccf745f_1              conda-forge/linux-64       2 MB
#   libcurl                       7.77.0  h2574ce0_0              installed
#   libcurl                       7.79.1  h2574ce0_1              conda-forge/linux-64     335 KB
#   libgcc-devel_linux-64          9.3.0  h7864c58_19             installed
#   libgcc-devel_linux-64          9.4.0  hd854feb_9              conda-forge/linux-64       4 MB
#   libgd                          2.3.2  h78a0170_0              installed
#   libgd                          2.3.3  h6ad9fb6_0              conda-forge/linux-64     279 KB
#   libgfortran-ng                 9.4.0  h69a702a_9              installed
#   libgfortran-ng                11.2.0  h69a702a_9              conda-forge/linux-64      19 KB
#   libgfortran5                   9.4.0  h62347ff_9              installed
#   libgfortran5                  11.2.0  h5c6108e_9              conda-forge/linux-64       2 MB
#   libgit2                        1.1.1  h3974521_0              installed
#   libgit2                        1.2.0  hee63804_0              conda-forge/linux-64     697 KB
#   libglib                       2.68.3  h3e27bee_0              installed
#   libglib                       2.68.4  h3e27bee_0              conda-forge/linux-64       3 MB
#   libopenblas                   0.3.15  pthreads_h8fe5266_1     installed
#   libopenblas                   0.3.17  pthreads_h8fe5266_1     conda-forge/linux-64       9 MB
#   libprotobuf                   3.16.0  h780b84a_0              installed
#   libprotobuf                   3.18.0  h780b84a_1              conda-forge/linux-64       3 MB
#   librsvg                       2.50.7  hc3c00ef_0              installed
#   librsvg                       2.52.0  hc3c00ef_0              conda-forge/linux-64       5 MB
#   libsolv                       0.7.18  h780b84a_0              installed
#   libsolv                       0.7.19  h780b84a_5              conda-forge/linux-64     445 KB
#   libssh2                        1.9.0  ha56f1ee_6              installed
#   libssh2                       1.10.0  ha56f1ee_2              conda-forge/linux-64     233 KB
#   libstdcxx-devel_linux-64       9.3.0  hb016644_19             installed
#   libstdcxx-devel_linux-64       9.4.0  hd854feb_9              conda-forge/linux-64      10 MB
#   libstdcxx-ng                   9.3.0  h6de172a_19             installed
#   libstdcxx-ng                  11.2.0  he4da1e4_9              conda-forge/linux-64       4 MB
#   libthrift                     0.14.2  he6d91bd_1              installed
#   libthrift                     0.15.0  he6d91bd_0              conda-forge/linux-64       5 MB
#   libuv                         1.41.0  h7f98852_0              installed
#   libuv                         1.41.1  h7f98852_0              conda-forge/linux-64       1 MB
#   libwebp                        1.2.0  h3452ae3_0              installed
#   libwebp                        1.2.1  h3452ae3_0              conda-forge/linux-64      84 KB
#   libwebp-base                   1.2.0  h7f98852_2              installed
#   libwebp-base                   1.2.1  h7f98852_0              conda-forge/linux-64     845 KB
#   llvmlite                      0.36.0  py39h1bbdace_0          installed
#   llvmlite                      0.37.0  py39h1bbdace_0          conda-forge/linux-64       3 MB
#   mako                           1.1.4  pyh44b312d_0            installed
#   mako                           1.1.5  pyhd8ed1ab_0            conda-forge/noarch        58 KB
#   mamba                         0.14.1  py39h951de11_0          installed
#   mamba                         0.16.0  py39h951de11_0          conda-forge/linux-64     787 KB
#   matplotlib-base                3.4.2  py39h2fa2bec_0          installed
#   matplotlib-base                3.4.3  py39h2fa2bec_1          conda-forge/linux-64       7 MB
#   matplotlib-inline              0.1.2  pyhd8ed1ab_2            installed
#   matplotlib-inline              0.1.3  pyhd8ed1ab_0            conda-forge/noarch        11 KB
#   modin                         0.10.0  py39h06a4308_0          installed
#   modin                         0.11.0  py39hf3d152e_0          conda-forge/linux-64      10 KB
#   mpc                            1.1.0  h04dde30_1009           installed
#   mpc                            1.2.1  h9f54685_0              conda-forge/linux-64     106 KB
#   mpfr                           4.0.2  he80fd80_1              installed
#   mpfr                           4.1.0  h9202a9a_1              conda-forge/linux-64       3 MB
#   nbclassic                      0.3.1  pyhd8ed1ab_1            installed
#   nbclassic                      0.3.2  pyhd8ed1ab_0            conda-forge/noarch        18 KB
#   nbclient                       0.5.3  pyhd8ed1ab_0            installed
#   nbclient                       0.5.4  pyhd8ed1ab_0            conda-forge/noarch        60 KB
#   nbconvert                      6.1.0  py39hf3d152e_0          installed
#   nbconvert                      6.2.0  py39hf3d152e_0          conda-forge/linux-64     529 KB
#   notebook                       6.4.0  pyha770c72_0            installed
#   notebook                       6.4.4  pyha770c72_0            conda-forge/noarch         6 MB
#   nss                             3.67  hb5efdd6_0              installed
#   nss                             3.69  hb5efdd6_0              conda-forge/linux-64       2 MB
#   numba                         0.53.1  py39h56b8d98_1          installed
#   numba                         0.54.0  py39h56b8d98_0          conda-forge/linux-64       4 MB
#   openblas                      0.3.15  pthreads_h4748800_1     installed
#   openblas                      0.3.17  pthreads_h4748800_1     conda-forge/linux-64      10 MB
#   orc                            1.6.8  h58a87f1_0              installed
#   orc                            1.7.0  h68e2c4e_0              conda-forge/linux-64       1 MB
#   packaging                       20.9  pyh44b312d_0            installed
#   packaging                       21.0  pyhd8ed1ab_0            conda-forge/noarch        35 KB
#   pandas                         1.2.4  py39hde0f152_0          installed
#   pandas                         1.3.3  py39hde0f152_0          conda-forge/linux-64      13 MB
#   pandoc                      2.14.0.3  h7f98852_0              installed
#   pandoc                        2.14.2  h7f98852_0              conda-forge/linux-64      12 MB
#   pandocfilters                  1.4.2  py_1                    installed
#   pandocfilters                  1.5.0  pyhd8ed1ab_0            conda-forge/noarch        11 KB
#   pango                         1.48.5  hb8ff022_0              installed
#   pango                        1.48.10  hb8ff022_1              conda-forge/linux-64     400 KB
#   patsy                          0.5.1  py_0                    installed
#   patsy                          0.5.2  pyhd8ed1ab_0            conda-forge/noarch       188 KB
#   pcre2                          10.36  h032f7d1_1              installed
#   pcre2                          10.37  h032f7d1_0              conda-forge/linux-64       1 MB
#   pg8000                        1.19.5  pyhd8ed1ab_0            installed
#   pg8000                        1.21.1  pyhd8ed1ab_0            conda-forge/noarch        26 KB
#   pillow                         8.2.0  py39hf95b381_1          installed
#   pillow                         8.3.2  py39ha612740_0          conda-forge/linux-64     701 KB
#   pip                           21.1.3  pyhd8ed1ab_0            installed
#   pip                           21.2.4  pyhd8ed1ab_0            conda-forge/noarch         1 MB
#   pooch                          1.4.0  pyhd8ed1ab_0            installed
#   pooch                          1.5.1  pyhd8ed1ab_0            conda-forge/noarch        45 KB
#   portalocker                    1.7.0  py39hf3d152e_1          installed
#   portalocker                    2.3.2  py39hf3d152e_0          conda-forge/linux-64      28 KB
#   prompt-toolkit                3.0.19  pyha770c72_0            installed
#   prompt-toolkit                3.0.20  pyha770c72_0            conda-forge/noarch       246 KB
#   prompt_toolkit                3.0.19  hd8ed1ab_0              installed
#   prompt_toolkit                3.0.20  hd8ed1ab_0              conda-forge/noarch         4 KB
#   protobuf                      3.16.0  py39he80948d_0          installed
#   protobuf                      3.18.0  py39he80948d_0          conda-forge/linux-64     341 KB
#   pyarrow                        4.0.1  py39h3ebc44c_2_cpu      installed
#   pyarrow                        5.0.0  py39h3ebc44c_8_cpu      conda-forge/linux-64       3 MB
#   pycurl                      7.43.0.6  py39h72e3413_1          installed
#   pycurl                        7.44.1  py39h72e3413_0          conda-forge/linux-64      71 KB
#   pygments                       2.9.0  pyhd8ed1ab_0            installed
#   pygments                      2.10.0  pyhd8ed1ab_0            conda-forge/noarch       760 KB
#   pymysql                       0.10.1  pyhd3deb0d_0            installed
#   pymysql                        1.0.2  pyhd8ed1ab_0            conda-forge/noarch        39 KB
#   python-dateutil                2.8.1  py_0                    installed
#   python-dateutil                2.8.2  pyhd8ed1ab_0            conda-forge/noarch       240 KB
#   pyzmq                         22.1.0  py39h37b5a0c_0          installed
#   pyzmq                         22.3.0  py39h37b5a0c_0          conda-forge/linux-64     536 KB
#   r-arrow                        4.0.1  r41h9c3ff4c_0           installed
#   r-arrow                        5.0.0  r41h9c3ff4c_1           conda-forge/linux-64       4 MB
#   r-base                         4.1.0  h9e01966_1              installed
#   r-base                         4.1.1  hb93adac_1              conda-forge/linux-64      25 MB
#   r-blob                         1.2.1  r41hc72bb7e_1           installed
#   r-blob                         1.2.2  r41hc72bb7e_0           conda-forge/noarch        64 KB
#   r-bslib                      0.2.5.1  r41hc72bb7e_0           installed
#   r-bslib                        0.3.0  r41hc72bb7e_0           conda-forge/noarch         4 MB
#   r-cachem                       1.0.5  r41hcfec24a_0           installed
#   r-cachem                       1.0.6  r41hcfec24a_0           conda-forge/linux-64      72 KB
#   r-caret                       6.0_88  r41hcfec24a_0           installed
#   r-caret                       6.0_89  r41hcfec24a_0           conda-forge/linux-64       6 MB
#   r-cli                          2.5.0  r41hc72bb7e_0           installed
#   r-cli                          3.0.1  r41h03ef668_1           conda-forge/linux-64     703 KB
#   r-cpp11                        0.3.1  r41hc72bb7e_0           installed
#   r-cpp11                        0.4.0  r41hc72bb7e_0           conda-forge/noarch       246 KB
#   r-data.table                  1.14.0  r41hcfec24a_0           installed
#   r-data.table                  1.14.2  r41hcfec24a_0           conda-forge/linux-64       2 MB
#   r-desc                         1.3.0  r41hc72bb7e_0           installed
#   r-desc                         1.4.0  r41hc72bb7e_0           conda-forge/noarch       557 KB
#   r-dials                        0.0.9  r41hc72bb7e_0           installed
#   r-dials                       0.0.10  r41hc72bb7e_0           conda-forge/noarch       775 KB
#   r-digest                      0.6.27  r41h03ef668_0           installed
#   r-digest                      0.6.28  r41h03ef668_0           conda-forge/linux-64     211 KB
#   r-dt                            0.18  r41hc72bb7e_0           installed
#   r-dt                            0.19  r41hc72bb7e_0           conda-forge/noarch         1 MB
#   r-future                      1.21.0  r41hc72bb7e_0           installed
#   r-future                      1.22.1  r41hc72bb7e_0           conda-forge/noarch       633 KB
#   r-gert                         1.3.1  r41hbd84cd2_0           installed
#   r-gert                         1.4.1  r41hfe241ca_0           conda-forge/linux-64     195 KB
#   r-googlesheets4                0.3.0  r41hc72bb7e_0           installed
#   r-googlesheets4                1.0.0  r41h785f33e_0           conda-forge/noarch       492 KB
#   r-haven                        2.4.2  r41h2713e49_0           installed
#   r-haven                        2.4.3  r41h2713e49_0           conda-forge/linux-64     390 KB
#   r-hms                          1.1.0  r41hc72bb7e_0           installed
#   r-hms                          1.1.1  r41hc72bb7e_0           conda-forge/noarch       106 KB
#   r-htmltools                  0.5.1.1  r41h03ef668_0           installed
#   r-htmltools                    0.5.2  r41h03ef668_0           conda-forge/linux-64     345 KB
#   r-htmlwidgets                  1.5.3  r41hc72bb7e_0           installed
#   r-htmlwidgets                  1.5.4  r41hc72bb7e_0           conda-forge/noarch       808 KB
#   r-httpuv                       1.6.1  r41h03ef668_0           installed
#   r-httpuv                       1.6.3  r41h03ef668_0           conda-forge/linux-64     880 KB
#   r-infer                        0.5.4  r41hc72bb7e_0           installed
#   r-infer                        1.0.0  r41hc72bb7e_0           conda-forge/noarch         2 MB
#   r-ipred                       0.9_11  r41hcfec24a_0           installed
#   r-ipred                       0.9_12  r41hcfec24a_0           conda-forge/linux-64     396 KB
#   r-isoband                      0.2.4  r41h03ef668_0           installed
#   r-isoband                      0.2.5  r41h03ef668_0           conda-forge/linux-64       2 MB
#   r-jpeg                       0.1_8.1  r41hcfec24a_1           installed
#   r-jpeg                         0.1_9  r41hcfec24a_0           conda-forge/linux-64      52 KB
#   r-knitr                         1.33  r41hc72bb7e_0           installed
#   r-knitr                         1.35  r41hc72bb7e_0           conda-forge/noarch         1 MB
#   r-lattice                    0.20_44  r41hcfec24a_0           installed
#   r-lattice                    0.20_45  r41hcfec24a_0           conda-forge/linux-64       1 MB
#   r-lava                         1.6.9  r41hc72bb7e_0           installed
#   r-lava                        1.6.10  r41hc72bb7e_0           conda-forge/noarch         3 MB
#   r-lhs                          1.1.1  r41h03ef668_0           installed
#   r-lhs                          1.1.3  r41h03ef668_1           conda-forge/linux-64     429 KB
#   r-lifecycle                    1.0.0  r41hc72bb7e_0           installed
#   r-lifecycle                    1.0.1  r41hc72bb7e_0           conda-forge/noarch       109 KB
#   r-magick                       2.7.2  r41h03ef668_1           installed
#   r-magick                       2.7.3  r41h03ef668_0           conda-forge/linux-64       5 MB
#   r-mgcv                        1.8_36  r41he454529_0           installed
#   r-mgcv                        1.8_37  r41he454529_0           conda-forge/linux-64       3 MB
#   r-mime                          0.11  r41hcfec24a_0           installed
#   r-mime                          0.12  r41hcfec24a_0           conda-forge/linux-64      51 KB
#   r-nlme                       3.1_152  r41h859d828_0           installed
#   r-nlme                       3.1_153  r41h859d828_0           conda-forge/linux-64       2 MB
#   r-openssl                      1.4.4  r41he36bf35_0           installed
#   r-openssl                      1.4.5  r41he36bf35_0           conda-forge/linux-64       1 MB
#   r-parallelly                  1.27.0  r41hc72bb7e_0           installed
#   r-parallelly                  1.28.1  r41hc72bb7e_0           conda-forge/noarch       286 KB
#   r-pillar                       1.6.1  r41hc72bb7e_0           installed
#   r-pillar                       1.6.3  r41hc72bb7e_0           conda-forge/noarch       990 KB
#   r-pkgload                      1.2.1  r41h03ef668_0           installed
#   r-pkgload                      1.2.2  r41h03ef668_0           conda-forge/linux-64     169 KB
#   r-proc                      1.17.0.1  r41h03ef668_0           installed
#   r-proc                        1.18.0  r41h03ef668_0           conda-forge/linux-64     854 KB
#   r-pryr                         0.1.4  r41h03ef668_1004        installed
#   r-pryr                         0.1.5  r41h03ef668_0           conda-forge/linux-64     236 KB
#   r-r6                           2.5.0  r41hc72bb7e_0           installed
#   r-r6                           2.5.1  r41hc72bb7e_0           conda-forge/noarch        89 KB
#   r-rcmdcheck                    1.3.3  r41hc72bb7e_3           installed
#   r-rcmdcheck                    1.4.0  r41h785f33e_0           conda-forge/noarch       174 KB
#   r-rcpp                         1.0.6  r41h03ef668_0           installed
#   r-rcpp                         1.0.7  r41h03ef668_0           conda-forge/linux-64       2 MB
#   r-rcurl                     1.98_1.3  r41hcfec24a_0           installed
#   r-rcurl                     1.98_1.5  r41hcfec24a_0           conda-forge/linux-64     989 KB
#   r-readr                        1.4.0  r41h03ef668_0           installed
#   r-readr                        2.0.2  r41h03ef668_0           conda-forge/linux-64     879 KB
#   r-recipes                     0.1.16  r41hc72bb7e_0           installed
#   r-recipes                     0.1.17  r41hc72bb7e_0           conda-forge/noarch         1 MB
#   r-remotes                      2.4.0  r41hc72bb7e_0           installed
#   r-remotes                      2.4.1  r41hc72bb7e_0           conda-forge/noarch       404 KB
#   r-reprex                       2.0.0  r41hc72bb7e_0           installed
#   r-reprex                       2.0.1  r41hc72bb7e_0           conda-forge/noarch       494 KB
#   r-rmarkdown                      2.9  r41hc72bb7e_1           installed
#   r-rmarkdown                     2.11  r41hc72bb7e_0           conda-forge/noarch         3 MB
#   r-rodbc                       1.3_17  r41hcfec24a_0           installed
#   r-rodbc                       1.3_19  r41hcfec24a_0           conda-forge/linux-64     879 KB
#   r-roxygen2                     7.1.1  r41h03ef668_0           installed
#   r-roxygen2                     7.1.2  r41h03ef668_0           conda-forge/linux-64     645 KB
#   r-rsqlite                      2.2.5  r41h03ef668_0           installed
#   r-rsqlite                      2.2.8  r41h03ef668_0           conda-forge/linux-64       1 MB
#   r-shadowtext                   0.0.8  r41hc72bb7e_0           installed
#   r-shadowtext                   0.0.9  r41hc72bb7e_0           conda-forge/noarch       246 KB
#   r-shiny                        1.6.0  r41hc72bb7e_0           installed
#   r-shiny                        1.7.0  r41h785f33e_0           conda-forge/noarch         4 MB
#   r-sparklyr                     1.7.1  r41hc72bb7e_0           installed
#   r-sparklyr                     1.7.2  r41hc72bb7e_0           conda-forge/noarch         5 MB
#   r-stringi                      1.6.2  r41hcabe038_0           installed
#   r-stringi                      1.7.4  r41hcabe038_0           conda-forge/linux-64     884 KB
#   r-summarytools                 0.9.9  r41hc72bb7e_0           installed
#   r-summarytools                 1.0.0  r41hc72bb7e_0           conda-forge/noarch         1 MB
#   r-survival                    3.2_11  r41hcfec24a_0           installed
#   r-survival                    3.2_13  r41hcfec24a_0           conda-forge/linux-64       7 MB
#   r-testthat                     3.0.3  r41h03ef668_0           installed
#   r-testthat                     3.0.4  r41h03ef668_0           conda-forge/linux-64       2 MB
#   r-tibble                       3.1.2  r41hcfec24a_0           installed
#   r-tibble                       3.1.4  r41hcfec24a_0           conda-forge/linux-64     765 KB
#   r-tidyr                        1.1.3  r41h03ef668_0           installed
#   r-tidyr                        1.1.4  r41h03ef668_0           conda-forge/linux-64     798 KB
#   r-tinytex                       0.32  r41hc72bb7e_0           installed
#   r-tinytex                       0.34  r41hc72bb7e_0           conda-forge/noarch       128 KB
#   r-utf8                         1.2.1  r41hcfec24a_0           installed
#   r-utf8                         1.2.2  r41hcfec24a_0           conda-forge/linux-64     162 KB
#   r-waldo                        0.2.5  r41hc72bb7e_0           installed
#   r-waldo                        0.3.1  r41hc72bb7e_0           conda-forge/noarch       103 KB
#   r-xfun                          0.24  r41h03ef668_0           installed
#   r-xfun                          0.26  r41h03ef668_0           conda-forge/linux-64     344 KB
#   ray-core                       1.4.0  py39h714431f_1          installed
#   ray-core                       1.6.0  py39h714431f_0          conda-forge/linux-64      30 MB
#   re2                       2021.06.01  h9c3ff4c_0              installed
#   re2                       2021.09.01  h9c3ff4c_0              conda-forge/linux-64     221 KB
#   reproc                        14.2.1  h36c2ea0_0              installed
#   reproc                        14.2.3  h7f98852_0              conda-forge/linux-64      28 KB
#   reproc-cpp                    14.2.1  h58526e2_0              installed
#   reproc-cpp                    14.2.3  h9c3ff4c_0              conda-forge/linux-64      20 KB
#   ruamel.yaml                  0.17.10  py39h3811e60_0          installed
#   ruamel.yaml                  0.17.16  py39h3811e60_0          conda-forge/linux-64     171 KB
#   s3fs                        2021.6.1  pyhd8ed1ab_0            installed
#   s3fs                        2021.9.0  pyhd8ed1ab_1            conda-forge/noarch        26 KB
#   scikit-image                  0.18.1  py39hde0f152_0          installed
#   scikit-image                  0.18.3  py39hde0f152_0          conda-forge/linux-64      12 MB
#   scikit-learn                  0.24.2  py39h4dfa638_0          installed
#   scikit-learn                     1.0  py39h7c5d8c9_1          conda-forge/linux-64       8 MB
#   scipy                          1.6.3  py39hee8e79c_0          installed
#   scipy                          1.7.1  py39hee8e79c_0          conda-forge/linux-64      22 MB
#   scramp                         1.4.0  pyhd8ed1ab_0            installed
#   scramp                         1.4.1  pyhd8ed1ab_0            conda-forge/noarch        12 KB
#   seaborn                       0.11.1  hd8ed1ab_1              installed
#   seaborn                       0.11.2  hd8ed1ab_0              conda-forge/noarch         4 KB
#   seaborn-base                  0.11.1  pyhd8ed1ab_1            installed
#   seaborn-base                  0.11.2  pyhd8ed1ab_0            conda-forge/noarch       223 KB
#   send2trash                     1.7.1  pyhd8ed1ab_0            installed
#   send2trash                     1.8.0  pyhd8ed1ab_0            conda-forge/noarch        17 KB
#   setuptools                    49.6.0  py39hf3d152e_3          installed
#   setuptools                    58.0.4  py39hf3d152e_2          conda-forge/linux-64     960 KB
#   sqlalchemy                    1.4.20  py39h3811e60_0          installed
#   sqlalchemy                    1.4.25  py39h3811e60_0          conda-forge/linux-64       2 MB
#   terminado                     0.10.1  py39hf3d152e_0          installed
#   terminado                     0.12.1  py39hf3d152e_0          conda-forge/linux-64      27 KB
#   threadpoolctl                  2.1.0  pyh5ca1d4c_0            installed
#   threadpoolctl                  2.2.0  pyh8a188c0_0            conda-forge/noarch        16 KB
#   tifffile                   2021.6.14  pyhd8ed1ab_0            installed
#   tifffile                   2021.8.30  pyhd8ed1ab_0            conda-forge/noarch       134 KB
#   tk                            8.6.10  h21135ba_1              installed
#   tk                            8.6.11  h27826a3_1              conda-forge/linux-64       3 MB
#   tqdm                          4.61.1  pyhd8ed1ab_0            installed
#   tqdm                          4.62.3  pyhd8ed1ab_0            conda-forge/noarch        80 KB
#   traitlets                      5.0.5  py_0                    installed
#   traitlets                      5.1.0  pyhd8ed1ab_0            conda-forge/noarch        82 KB
#   typing-extensions           3.10.0.0  hd8ed1ab_0              installed
#   typing-extensions           3.10.0.2  hd8ed1ab_0              conda-forge/noarch         8 KB
#   typing_extensions           3.10.0.0  pyha770c72_0            installed
#   typing_extensions           3.10.0.2  pyha770c72_0            conda-forge/noarch        28 KB
#   tzlocal                          2.1  pyh9f0ad1d_0            installed
#   tzlocal                          3.0  py39hf3d152e_2          conda-forge/linux-64      27 KB
#   urllib3                       1.26.6  pyhd8ed1ab_0            installed
#   urllib3                       1.26.7  pyhd8ed1ab_0            conda-forge/noarch       100 KB
#   wheel                         0.36.2  pyhd3deb0d_0            installed
#   wheel                         0.37.0  pyhd8ed1ab_1            conda-forge/noarch        31 KB
#   zipp                           3.4.1  pyhd8ed1ab_0            installed
#   zipp                           3.5.0  pyhd8ed1ab_0            conda-forge/noarch        12 KB
#
#   Summary:
#
#   Install: 17 packages
#   Change: 27 packages
#   Upgrade: 207 packages
#
#   Total download: 526 MB
#
# ─────────────────────────────────────────────────────────────────────────────────────────────────
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
# done
